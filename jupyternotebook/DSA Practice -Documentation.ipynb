# %%
arr= [1,2,3,4]
print(arr[-1])
# Out:
# 4

# %%
arr= [1,2,3,4,5]
mid= len(arr)//2 # len-prints length
print(arr[mid])
# Out:
# 3

# %%
arr= [1,2,3,4,5]
print(len(arr))
# Out:
# 5

# %%
arr= [1,2,3,4,5]
arr.append(6)
print(arr)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
arr=[1, 2, 3, 4, 5, 6]
arr.pop(2)
print(arr)
# Out:
# [1, 2, 4, 5, 6]

# %%
[1, 2, 3, 4, 5, 6]
arr.pop()
print(arr)
# Out:
# [1, 2, 4, 5]

# %%
arr=[1, 2, 3, 4, 5, 6]
print(arr[-3:])
# Out:
# [4, 5, 6]

# %%
arr=[1, 2, 3, 4, 5, 6]
print(arr[:3])
# Out:
# [1, 2, 3]

# %%
arr=[1, 2, 3, 4, 5, 6]
for num in arr:
    print(num)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6

# %%
arr=['apple','banana','cherry']
for i, item in enumerate(arr): #enumerate gives index and value in loop, i is index
    print(i,item)
# Out:
# 0 apple
# 1 banana
# 2 cherry

# %%
arr=['apple','banana','cherry']
for item in arr:
    print(item)
# Out:
# apple
# banana
# cherry

# %%
arr=[1,2,3,4,5,6]
total=0
for num in arr:
    total+= num
print(total)
# Out:
# 21

# %%
#searching if 3 is in list
arr=[1,2,3,4,5,6]
for num in arr:
    if num==3:
        print("Found")
        break
# Out:
# Found

# %%
#Index of 30 in list 
arr= [10,20,30,40,50]
for i in range (len(arr)):
    if arr[i]==30:
     print(i)
# Out:
# 2

# %%
arr= [1,2,2,2,3,3,4,5,5,6,6,6,4,4,] #counting 2s
count=0
for num in arr:
    if num==4:
        count+=1
print(count)
# Out:
# 3
# 4

# %%
arr= [1,-1,-2,-3,4,-6,-8] #replace/modify
for i in range(len(arr)):
 if arr[i]<0:
     arr[i]=0
print(arr)
# Out:
# [1, 0, 0, 0, 4, 0, 0]

# %%
arr=[1, 0, 0, 0, 4, 0, 0]
for i in range(len(arr)):
    arr[i]= arr[i]*2
print(arr)
# Out:
# [2, 0, 0, 0, 8, 0, 0]

# %%
#sorting
arr=[3,1,4,1,5,9]
for i in range(len(arr)):
 for j in range(i+1, len(arr)):
     if arr[i]>arr[j]:
         arr[i],arr[j]= arr[j],arr[i]
print(arr)
# Out:
# [1, 1, 3, 4, 5, 9]

# %%
arr=[3,1,4,1,5,9]
arr.sort()
print(arr)
# Out:
# [1, 1, 3, 4, 5, 9]

# %%
#linkedlist
