# %%
def square(n) :
    return n*n
    num= int(input("Enter a num"))
    print(f"The sq of {num} is {num*num}")

# %%
def is_even(n):
    if n%2==0:
        return True
    else :
        return False
    n=input(int("Enter a num"))
    print(is_even(n))
