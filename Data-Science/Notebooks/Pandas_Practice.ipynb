# %%
import numpy as np
import pandas as pd

# %%
pd.Series ([3,7,10,-2])
# Out:
# 0     3
# 1     7
# 2    10
# 3    -2
# dtype: int64

# %%
series=pd.Series ([3,7,10,-2], index=['a','b','c','d'])
series
# Out:
# a     3
# b     7
# c    10
# d    -2
# dtype: int64

# %%
series['b']
# Out:
# np.int64(7)

# %%
np_array=np.array([10,20,30,40,50,60])
list_1=[10,20,30,40,50,60]
dictionary= {'a':10,'b':20,'c':30,'d':40,'e':50,'f':60}
labels=['a','b','c','d','e','f']

# %%
pd.Series(np_array,labels)
# Out:
# a    10
# b    20
# c    30
# d    40
# e    50
# f    60
# dtype: int64

# %%
pd.Series(list_1, labels)
# Out:
# a    10
# b    20
# c    30
# d    40
# e    50
# f    60
# dtype: int64

# %%
pd.Series(dictionary)
# Out:
# a    10
# b    20
# c    30
# d    40
# e    50
# f    60
# dtype: int64

# %%
pd.Series(["Strings",10,print])
# Out:
# 0                      Strings
# 1                           10
# 2    <built-in function print>
# dtype: object

# %% [markdown]
# series

# %% [markdown]
# Series.to_dict()
